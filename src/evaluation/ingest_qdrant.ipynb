# %%
import os
import glob
import re
import uuid
import torch
import torch.nn.functional as F
from transformers import AutoModel, AutoTokenizer, AutoModelForMaskedLM, BitsAndBytesConfig
from qdrant_client import QdrantClient, models
from qdrant_client.models import PointStruct, SparseVector, Distance, VectorParams, SparseVectorParams
from langchain_text_splitters import MarkdownHeaderTextSplitter

# ==========================================
# 1. KONFIGURASI DAN SETUP
# ==========================================

# Path Folder Markdown (SESUAIKAN JIKA PERLU)
FOLDER_PATH = r"C:\\Users\\Ilmu Komputer\\OneDrive\\Desktop\\portofolio\\RAG\\defi-rag-agent\\src\\evaluation\\data_md\\real_md"

# Model IDs
DENSE_MODEL_ID = "Qwen/Qwen3-Embedding-4B"
SPARSE_MODEL_ID = "naver/splade-v3"
QDRANT_PATH = "./qdrant_custom_db"
COLLECTION_NAME = "hybrid_qwen_splade_optimized"

# Setup Device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"🚀 Running on: {device}")

# Konfigurasi Kuantisasi 4-bit (Hemat VRAM GPU)
bnb_config = None
if device == "cuda":
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16
    )

# ==========================================
# 2. CLASS EMBEDDER (DENSE + SPARSE)
# ==========================================

def last_token_pool(last_hidden_states: torch.Tensor, attention_mask: torch.Tensor) -> torch.Tensor:
    """Helper function khusus untuk Qwen/GTE embedding agar ambil token terakhir"""
    left_padding = (attention_mask[:, -1].sum() == attention_mask.shape[0])
    if left_padding:
        return last_hidden_states[:, -1]
    else:
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = last_hidden_states.shape[0]
        return last_hidden_states[torch.arange(batch_size, device=last_hidden_states.device), sequence_lengths]

class CustomEmbedder:
    def __init__(self):
        print("⏳ Loading Dense Model (Qwen 4-bit)...")
        self.dense_tokenizer = AutoTokenizer.from_pretrained(DENSE_MODEL_ID, trust_remote_code=True)
        self.dense_model = AutoModel.from_pretrained(
            DENSE_MODEL_ID,
            trust_remote_code=True,
            quantization_config=bnb_config,
            device_map="auto" if device == "cuda" else None,
            torch_dtype=torch.float16 if device == "cuda" else torch.float32
        )
        if device == "cpu": self.dense_model.to("cpu")

        print("⏳ Loading Sparse Model (Splade v3)...")
        self.sparse_tokenizer = AutoTokenizer.from_pretrained(SPARSE_MODEL_ID)
        self.sparse_model = AutoModelForMaskedLM.from_pretrained(SPARSE_MODEL_ID)
        self.sparse_model.to(device)

    def get_dense_vector(self, text):
        inputs = self.dense_tokenizer(
            text, max_length=8192, padding=True, truncation=True, return_tensors='pt'
        )
        inputs = {k: v.to(self.dense_model.device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = self.dense_model(**inputs)
            embeddings = last_token_pool(outputs.last_hidden_state, inputs['attention_mask'])
            embeddings = F.normalize(embeddings, p=2, dim=1)
            
        return embeddings[0].cpu().tolist()

    def get_sparse_vector(self, text):
        inputs = self.sparse_tokenizer(
            text, return_tensors="pt", padding=True, truncation=True
        )
        inputs = {k: v.to(self.sparse_model.device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = self.sparse_model(**inputs)
        
        # SPLADE Logic: ReLU -> Log -> Max Pooling
        logits = outputs.logits[0]
        relu_log = torch.log(1 + torch.relu(logits))
        # Attention mask filter
        attention_mask = inputs["attention_mask"][0].unsqueeze(-1)
        weighted_log = relu_log * attention_mask
        
        max_val, _ = torch.max(weighted_log, dim=0)
        
        # Extract Non-Zero indices
        indices = torch.nonzero(max_val).squeeze().cpu().tolist()
        values = max_val[indices].cpu().tolist()
        
        # Safety check untuk scalar/single output
        if isinstance(indices, int):
            indices = [indices]
            values = [values]
            
        return SparseVector(indices=indices, values=values)

# ==========================================
# 3. SETUP DATABASE QDRANT
# ==========================================

embedder = CustomEmbedder()

print(f"\n💽 Membuka database Qdrant lokal di: {QDRANT_PATH}")
client = QdrantClient(path=QDRANT_PATH)

if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

print("⚙️ Membuat Collection baru...")
client.create_collection(
    collection_name=COLLECTION_NAME,
    vectors_config={
        "dense_vector": VectorParams(size=2560, distance=Distance.COSINE) # Qwen size=1536/2560 depending on model version, Qwen2.5-1.5B usually 1536, check output. Qwen-4B might be larger. 
        # UPDATE: Qwen-Embedding default is usually compatible. Let's assume standard logic.
        # NOTE: Jika error size mismatch, cek len(d_vec) sekali print.
    },
    sparse_vectors_config={
        "sparse_vector": SparseVectorParams()
    }
)

# ==========================================
# 4. FUNGSI UTILITY (CLEANING & SPLITTING)
# ==========================================

def clean_title(filename):
    """Membersihkan nama file dari ekstensi dan timestamp (misal: _250130_133808)"""
    name = os.path.splitext(filename)[0]
    # Regex: Hapus pola [-_] diikuti minimal 6 digit angka sampai akhir string
    name = re.sub(r'[-_]\d{6,}.*', '', name)
    # Ganti separator dengan spasi
    name = name.replace("-", " ").replace("_", " ")
    return " ".join(name.split()) # Hapus spasi ganda

headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3")]
md_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

md_files = glob.glob(os.path.join(FOLDER_PATH, "*.md"))
print(f"📂 Ditemukan {len(md_files)} file Markdown.")

# ==========================================
# 5. PROSES EMBEDDING & UPSERT
# ==========================================

points = []
print("🚀 Mulai proses embedding...")

# LOOP 1: FILE
for file_index, file_path in enumerate(md_files):
    file_name = os.path.basename(file_path)
    
    # BERSIHKAN JUDUL
    doc_title = clean_title(file_name)
    
    with open(file_path, "r", encoding="utf-8") as f:
        file_content = f.read()
        
    docs = md_splitter.split_text(file_content)
    total_chunks = len(docs)
    
    print(f"\n📄 File [{file_index+1}/{len(md_files)}]: {file_name}")
    print(f"   🧹 Clean Title: '{doc_title}'")

    # LOOP 2: CHUNK
    for i, doc in enumerate(docs):
        raw_content = doc.page_content.strip()
        if not raw_content: continue

        # Ambil header hierarchy
        header_keys = [name for _, name in headers_to_split_on]
        found_headers = []
        for key in header_keys:
            if key in doc.metadata:
                found_headers.append(doc.metadata[key])
        
        # KONSTRUKSI BREADCRUMB
        # [Judul File, Header 1, Header 2]
        context_chain = [doc_title] + found_headers
        breadcrumb_str = " > ".join(context_chain)
        
        # FORMAT FINAL TEXT
        # Penting: Spasi di sekitar titik dua agar SPLADE & Qwen paham pemisahan
        final_text = f"{breadcrumb_str} : {raw_content}"

        print(f"   👉 Chunk [{i+1}/{total_chunks}] | {breadcrumb_str}")

        # Create Vectors
        try:
            d_vec = embedder.get_dense_vector(final_text)
            s_vec = embedder.get_sparse_vector(final_text)
            
            # Validasi Size Vector saat runtime pertama kali (untuk safety)
            if file_index == 0 and i == 0:
                print(f"   📏 Detected Dense Vector Size: {len(d_vec)}")

            metadata = doc.metadata
            metadata["source_file"] = file_name
            metadata["doc_title"] = doc_title
            metadata["chunk_index"] = i
            
            points.append(PointStruct(
                id=str(uuid.uuid4()), 
                vector={
                    "dense_vector": d_vec,
                    "sparse_vector": s_vec
                },
                payload={
                    "text": final_text,
                    "original_content": raw_content,
                    "metadata": metadata
                }
            ))
        except Exception as e:
            print(f"   ❌ Error embedding chunk: {e}")

# Upload ke Qdrant
if points:
    print(f"\n⬆️ Mengupload {len(points)} points ke Qdrant...")
    # Batch upsert jika data sangat banyak (optional optimization)
    BATCH_SIZE = 50
    for i in range(0, len(points), BATCH_SIZE):
        batch = points[i:i+BATCH_SIZE]
        client.upsert(collection_name=COLLECTION_NAME, points=batch)
        print(f"   Saved batch {i} - {i+len(batch)}")
    print("✅ Semua data berhasil diupload!")
else:
    print("⚠️ Tidak ada data point yang dihasilkan.")

# ==========================================
# 6. FUNGSI PENCARIAN (TESTING)
# ==========================================

def search_hybrid(query_text):
    print(f"\n🔍 Searching for: '{query_text}'")
    
    q_dense = embedder.get_dense_vector(query_text)
    q_sparse = embedder.get_sparse_vector(query_text)
    
    results = client.query_points(
        collection_name=COLLECTION_NAME,
        prefetch=[
            models.Prefetch(
                query=q_dense, using="dense_vector", limit=20
            ),
            models.Prefetch(
                query=q_sparse, using="sparse_vector", limit=20
            ),
        ],
        query=models.FusionQuery(fusion=models.Fusion.RRF),
        limit=3
    )
    
    for i, hit in enumerate(results.points):
        print(f"\n🏆 Rank {i+1} (Score: {hit.score:.4f})")
        print(f"   📄 Source: {hit.payload['metadata'].get('doc_title', 'Unknown')}")
        print(f"   📝 Content Snippet: {hit.payload['text'][:200]}...")

search_hybrid("Bagaimana struktur kurikulum?")
# Out:
# 🚀 Running on: cuda
# ⏳ Loading Dense Model (Qwen 4-bit)...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ⏳ Loading Sparse Model (Splade v3)...
#
# 💽 Membuka database Qdrant lokal di: ./qdrant_custom_db
# ⚙️ Membuat Collection baru...
# 📂 Ditemukan 13 file Markdown.
# 🚀 Mulai proses embedding...
#
# 📄 File [1/13]: Dukungan-Pelaksanaan-Kebijakan-Efisiensi-Belanja-APBN-Tahun-Anggaran-2025pdf.md
#    🧹 Clean Title: 'Dukungan Pelaksanaan Kebijakan Efisiensi Belanja APBN Tahun Anggaran 2025pdf'
#    👉 Chunk [1/1] | Dukungan Pelaksanaan Kebijakan Efisiensi Belanja APBN Tahun Anggaran 2025pdf > KEMENTERIAN KEUANGAN REPUBLIK INDONESIA > DIREKTORAT JENDERAL PERBENDAHARAAN
#    📏 Detected Dense Vector Size: 2560
#
# 📄 File [2/13]: Dukungan-Pelaksanaan-Kebijakan-Pemerintahpdf.md
#    🧹 Clean Title: 'Dukungan Pelaksanaan Kebijakan Pemerintahpdf'
#    👉 Chunk [1/1] | Dukungan Pelaksanaan Kebijakan Pemerintahpdf > KEMENTERIAN KEUANGAN REPUBLIK INDONESIA > DIREKTORAT JENDERAL PERBENDAHARAAN
#
# 📄 File [3/13]: Efisiensi-KL-TA-2025_250130_133808.md
#    🧹 Clean Title: 'Efisiensi KL TA 2025'
#    👉 Chunk [1/2] | Efisiensi KL TA 2025 > REPUBLIK INDONESIA
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
#    👉 Chunk [2/2] | Efisiensi KL TA 2025 > REPUBLIK INDONESIA > IDENTIFIKASI RENCANA EFISIENSI
#
# 📄 File [4/13]: Inpres-1-Tahun_2025.md
#    🧹 Clean Title: 'Inpres 1 Tahun 2025'
#    👉 Chunk [1/3] | Inpres 1 Tahun 2025
#    👉 Chunk [2/3] | Inpres 1 Tahun 2025 > PRESIDEN REPUBLIK INDONESIA > EFISIENSI BELANJA DALAM PELAKSANAAN ANGGARAN PENDAPATAN DAN BELANJA NEGARA DAN ANGGARAN PENDAPATAN DAN BELANJA DAERAH > TAHUN ANGGARAN 2025
#    👉 Chunk [3/3] | Inpres 1 Tahun 2025 > PRESIDEN REPUBLIK INDONESIA > 2. Menteri Dalam Negeri untuk:
#
# 📄 File [5/13]: panduan-app-spkdriver.md
#    🧹 Clean Title: 'panduan app spkdriver'
#    👉 Chunk [1/4] | panduan app spkdriver
#    👉 Chunk [2/4] | panduan app spkdriver > PANDUAN > PENGGUNAAN APLIKASI SPK-DRIVER USER DRIVER > Universitas Pendidikan Ganesha
#    👉 Chunk [3/4] | panduan app spkdriver > PANDUAN APP SPK-DRIVER
#    👉 Chunk [4/4] | panduan app spkdriver > PANDUAN APP SPK-DRIVER > 8. Data berhasil ditambahkan dan halama serta status sudah berubah
#
# 📄 File [6/13]: panduan_prestasi.md
#    🧹 Clean Title: 'panduan prestasi'
#    👉 Chunk [1/16] | panduan prestasi > PANDUAN > SIMKATMAWA
#    👉 Chunk [2/16] | panduan prestasi > Proses Bisnis SIMKATMAWA
#    👉 Chunk [3/16] | panduan prestasi > Proses Bisnis SIMKATMAWA > Alur Singkat SIMKATMAWA :
#    👉 Chunk [4/16] | panduan prestasi > Alur Pengajuan Program Kerja
#    👉 Chunk [5/16] | panduan prestasi > Alur Pengajuan Proposal
#    👉 Chunk [6/16] | panduan prestasi > PANDUAN LOGIN :
#    👉 Chunk [7/16] | panduan prestasi > PANDUAN LOGIN : > 4. Menu Pembiayaan
#    👉 Chunk [8/16] | panduan prestasi > 5. Menu Prestasi > Interface Screenshot - Daftar Prestasi Lomba
#    👉 Chunk [9/16] | panduan prestasi > 5. Menu Prestasi > A. Lomba Mandiri
#    👉 Chunk [10/16] | panduan prestasi > 5. Menu Prestasi > Form Interface Screenshot
#    👉 Chunk [11/16] | panduan prestasi > 5. Menu Prestasi > Form Detail Lomba
#    👉 Chunk [12/16] | panduan prestasi > 5. Menu Prestasi > Form Dosen Pembimbing. Klik Simpan jika data yang diinputkan dirasa sudah benar.
#    👉 Chunk [13/16] | panduan prestasi > 5. Menu Prestasi > C. Sertifikasi
#    👉 Chunk [14/16] | panduan prestasi > 5. Menu Prestasi > D. Wirausaha
#    👉 Chunk [15/16] | panduan prestasi > 5. Menu Prestasi > Detail Wirausaha
#    👉 Chunk [16/16] | panduan prestasi > SELAMAT MENCOBA 😊
#
# 📄 File [7/13]: pengumuman_beasiswa_ganesha-2025.md
#    🧹 Clean Title: 'pengumuman beasiswa ganesha 2025'
#    👉 Chunk [1/8] | pengumuman beasiswa ganesha 2025
#    👉 Chunk [2/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN
#    👉 Chunk [3/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN > SELEKSI BEASISWA GANESHA TAHUN 2025
#    👉 Chunk [4/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN > A. Persyaratan > (1) Bagi Mahasiswa Tidak Mampu
#    👉 Chunk [5/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN > A. Persyaratan > (2) Bagi Mahasiswa Berprestasi
#    👉 Chunk [6/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN > (3) Mahasiswa yang Aktif Berkegiatan di Organisasi Mahasiswa (BEM REMA)
#    👉 Chunk [7/8] | pengumuman beasiswa ganesha 2025 > PENGUMUMAN > B. Prosedur Seleksi
#    👉 Chunk [8/8] | pengumuman beasiswa ganesha 2025 > LEMBAR PENILAIAN KEPRIBADIAN CALON PELAMAR BEASISWA GANESHA UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [8/13]: Signed-SK-Rektor-tentang-Kewajiban-Publikasi-dan-Sitasi-2025.md
#    🧹 Clean Title: 'Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025'
#    👉 Chunk [1/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > KEMENTERIAN PENDIDIKAN TINGGI, SAINS, DAN TEKNOLOGI > UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [2/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > KEPUTUSAN > TENTANG > REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [3/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN
#    👉 Chunk [4/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > I. DEFINISI KARYA ILMIAH
#    👉 Chunk [5/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > II. KLASIFIKASI KARYA ILMIAH > 1. JURNAL ILMIAH
#    👉 Chunk [6/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > 2. ARTIKEL YANG DISAJIKAN DALAM SEMINAR (PROSIDING) > A. Artikel Disajikan dalam Seminar Internasional
#    👉 Chunk [7/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > 2. ARTIKEL YANG DISAJIKAN DALAM SEMINAR (PROSIDING) > B. Artikel Disajikan dalam Seminar Nasional
#    👉 Chunk [8/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > 3. KEKAYAAN INTELEKTUAL
#    👉 Chunk [9/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > III. KEWAJIBAN PUBLIKASI DAN KEKAYAAN INTELEKTUAL > A. KETENTUAN UMUM
#    👉 Chunk [10/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > A.2. Kekayaan Intelektual (KI)
#    👉 Chunk [11/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > B. KETENTUAN KHUSUS
#    👉 Chunk [12/12] | Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > LAMPIRAN > IV. KEWAJIBAN SITASI
#
# 📄 File [9/13]: SK-2525-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-UNDIKSHA-2024.md
#    🧹 Clean Title: 'SK 2525 DUTA KETERBUKAAN INFORMASI PUBLIK UNDIKSHA 2024'
#    👉 Chunk [1/4] | SK 2525 DUTA KETERBUKAAN INFORMASI PUBLIK UNDIKSHA 2024
#    👉 Chunk [2/4] | SK 2525 DUTA KETERBUKAAN INFORMASI PUBLIK UNDIKSHA 2024 > UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2024
#    👉 Chunk [3/4] | SK 2525 DUTA KETERBUKAAN INFORMASI PUBLIK UNDIKSHA 2024 > UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2024 > MEMUTUSKAN:
#    👉 Chunk [4/4] | SK 2525 DUTA KETERBUKAAN INFORMASI PUBLIK UNDIKSHA 2024 > LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [10/13]: SK-3299-SK-Tim-Pejabat-PPID-Undiksha-2023.md
#    🧹 Clean Title: 'SK 3299 SK Tim Pejabat PPID Undiksha 2023'
#    👉 Chunk [1/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023
#    👉 Chunk [2/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > NOMOR 3299/UN48/PT/2023 > TENTANG
#    👉 Chunk [3/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [4/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > Tim Pertimbangan Pelayanan Informasi
#    👉 Chunk [5/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > Publikasi
#    👉 Chunk [6/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > Dokumentasi dan Arsip Layanan Informasi
#    👉 Chunk [7/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > TIK
#    👉 Chunk [8/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > Penanganan Pengaduan Rektorat
#    👉 Chunk [9/9] | SK 3299 SK Tim Pejabat PPID Undiksha 2023 > LAMPIRAN > Penanganan Pengaduan Fakultas/Pascasarjana/Lembaga (IT/Publikasi dan Humas)
#
# 📄 File [11/13]: SK-814-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-MAHASISWA-TAHUN-2025.md
#    🧹 Clean Title: 'SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025'
#    👉 Chunk [1/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025
#    👉 Chunk [2/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025
#    👉 Chunk [3/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > Menimbang :
#    👉 Chunk [4/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > Mengingat :
#    👉 Chunk [5/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > MEMUTUSKAN:
#    👉 Chunk [6/6] | SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [12/13]: SK-815-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-ALUMNI-TAHUN-2025.md
#    🧹 Clean Title: 'SK 815 DUTA KETERBUKAAN INFORMASI PUBLIK ALUMNI TAHUN 2025'
#    👉 Chunk [1/2] | SK 815 DUTA KETERBUKAAN INFORMASI PUBLIK ALUMNI TAHUN 2025
#    👉 Chunk [2/2] | SK 815 DUTA KETERBUKAAN INFORMASI PUBLIK ALUMNI TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) ALUMNI UNIVERSITAS PENDIDIKAN GANESHA MASA BHAKTI TAHUN 2025-2026 > REKTOR UNIVERSITAS PENDIDIKAN GANESHA,
#
# 📄 File [13/13]: SK-Daftar-Informasi-Informasi-Publik-Undiksha-Tahun-2024.md
#    🧹 Clean Title: 'SK Daftar Informasi Informasi Publik Undiksha Tahun 2024'
#    👉 Chunk [1/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024
#    👉 Chunk [2/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > NOMOR 571/UN48/PT/2024 > TENTANG
#    👉 Chunk [3/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > Menimbang
#    👉 Chunk [4/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > Mengingat
#    👉 Chunk [5/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > MEMUTUSKAN:
#    👉 Chunk [6/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DAFTAR INFORMASI PUBLIK YANG WAJIB DISEDIAKAN DAN DIUMUMKAN SECARA BERKALA
#    👉 Chunk [7/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > DAFTAR INFORMASI PUBLIK YANG WAJIB TERSEDIA SETIAP SAAT
#    👉 Chunk [8/8] | SK Daftar Informasi Informasi Publik Undiksha Tahun 2024 > DAFTAR INFORMASI DIKECUALIKAN YANG HABIS JANGKA WAKTU PENGECUALIAN SEBAGAI INFORMASI TERBUKA
#
# ⬆️ Mengupload 76 points ke Qdrant...
#    Saved batch 0 - 50
#    Saved batch 50 - 76
# ✅ Semua data berhasil diupload!
#
# 🔍 Searching for: 'Bagaimana struktur kurikulum?'
#
# 🏆 Rank 1 (Score: 0.5000)
#    📄 Source: panduan prestasi
#    📝 Content Snippet: panduan prestasi > SELAMAT MENCOBA 😊 : [Decorative footer with teal/green and blue geometric design elements]...
#
# 🏆 Rank 2 (Score: 0.5000)
#    📄 Source: Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025
#    📝 Content Snippet: Signed SK Rektor tentang Kewajiban Publikasi dan Sitasi 2025 > KEPUTUSAN > TENTANG > REKTOR UNIVERSITAS PENDIDIKAN GANESHA : **Menimbang** : a. bahwa dalam rangka meningkatkan kualitas lulusan dan men...
#
# 🏆 Rank 3 (Score: 0.3333)
#    📄 Source: panduan prestasi
#    📝 Content Snippet: panduan prestasi > Alur Pengajuan Program Kerja : ```mermaid
# flowchart TD
# A[Mulai] --> B[Input program]
# B --> C[Review]
# C --> D{Sesuai?}
# D -->|Ya| E[Menyetujui]
# D -->|belum| B
# E --> F[Selesai]
#
# subgra...

# %%
search_hybrid("Siapa Penanggung jawab pertama dalam struktur Duta KIP Alumni?")
# Out:
# 🔍 Searching for: 'Siapa Penanggung jawab pertama dalam struktur Duta KIP Alumni?'
#
# 🏆 Rank 1 (Score: 1.0000)
#    📄 Source: SK 815 DUTA KETERBUKAAN INFORMASI PUBLIK ALUMNI TAHUN 2025
#    📝 Content Snippet: SK 815 DUTA KETERBUKAAN INFORMASI PUBLIK ALUMNI TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) ALUMNI UNIVERSITAS PENDIDIKAN GANESHA MASA BHAKTI...
#
# 🏆 Rank 2 (Score: 0.6667)
#    📄 Source: SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025
#    📝 Content Snippet: SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN...
#
# 🏆 Rank 3 (Score: 0.4000)
#    📄 Source: SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025
#    📝 Content Snippet: SK 814 DUTA KETERBUKAAN INFORMASI PUBLIK MAHASISWA TAHUN 2025 > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN...

# %%
search_hybrid("Siapa saja Dosen Pendamping dalam SK ini?")
# Out:
# 🔍 Query: 'Siapa saja Dosen Pendamping dalam SK ini?'
#    Score: 0.5333 | Text: LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA: **NOMOR** 814/UN48/KM.05.04/2025
# **TANGGAL** 17 MARET 2025
# **TENTANG** DUTA KETERBUKAAN INFORMASI PUBLIK UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025
# **Pengarah** : Prof. Dr. I Wayan Lasmawan, M.Pd.
# **Penanggung jawab** :
# 1. Prof. Dr. Gede Rasben Dantes, S.T., M.T.I.
# 2. Prof.Dr. I Wayan Artanayasa, S.Pd., M.Pd., AIFO-FIT.
# 3. Prof. Dr. Drs. I Ketut Sudiana, M.Kes.
# 4. Drs. I Made Yasa, M.Pd.
# 5. Prof. Dr. Komang Setemen, S.Si., M.T.
# 6. I Made Karunia, S.T., M.Kom.
# **Dosen Pendamping** :
# 1. Dr. Kadek Wirahyuni, S.Pd., M.Pd.
# 2. I Kadek Edi Yudiana, M.Pd.
# **Ketua** : Komang Danda Widya Anugrah
# <table>
# <thead>
# <tr>
# <th></th>
# <th>Nama</th>
# <th>NIM</th>
# <th>Prodi</th>
# <th>Fakultas</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="9">Anggota</td>
# <td>Kadek Ayu Pitriyani</td>
# <td>2215011021</td>
# <td>Pendidikan Kesejahteraan Keluarga</td>
# <td>FTK</td>
# </tr>
# <tr>
# <td>Gede Ngurah Dananjaya Kajeng</td>
# <td>2315051024</td>
# <td>Pendidikan Teknik Informatika</td>
# <td>FTK</td>
# </tr>
# <tr>
# <td>Nadita Sulastri Br Purba</td>
# <td>2418031014</td>
# <td>Kebidanan</td>
# <td>FK</td>
# </tr>
# <tr>
# <td>Gede Pradnyana Putra</td>
# <td>2318011062</td>
# <td>Kedokteran</td>
# <td>FK</td>
# </tr>
# <tr>
# <td>Kadek Meitha Yesi Pranjani Maharani</td>
# <td>2311031221</td>
# <td>Pendidikan Guru Sekolah Dasar</td>
# <td>FIP</td>
# </tr>
# <tr>
# <td>Luh Gede Nurita Handayani</td>
# <td>2211061011</td>
# <td>Pendidikan Guru Pendidikan Anak Usia Dini</td>
# <td>FIP</td>
# </tr>
# <tr>
# <td>Made Surya Putra Mahadheva</td>
# <td>2312011005</td>
# <td>Pendidikan Bahasa Indonesia</td>
# <td>FBS</td>
# </tr>
# <tr>
# <td>Ketut Rosa Indahyani</td>
# <td>2313021004</td>
# <td>Pendidikan Fisika</td>
# <td>FMIPA</td>
# </tr>
# <tr>
# <td>Ni Kadek Cinta Eka Putri Jayanti</td>
# <td>2213021007</td>
# <td>Pendidikan Fisika</td>
# <td>FMIPA</td>
# </tr>
# </tbody>
# </table>
# ---
# <table>
# <tr>
# <td>Ni Kadek Carmiani</td>
# <td>2216011025</td>
# <td>PJKR</td>
# <td>FOK</td>
# </tr>
# <tr>
# <td>I Kadek Nova pramana putra</td>
# <td>2316011026</td>
# <td>PJKR</td>
# <td>FOK</td>
# </tr>
# <tr>
# <td>Gede Eka Sidi Artama</td>
# <td>2214101073</td>
# <td>Ilmu Hukum</td>
# <td>FHIS</td>
# </tr>
# <tr>
# <td>Kunti Afrida Maharani</td>
# <td>2314101108</td>
# <td>Ilmu Hukum</td>
# <td>FHIS</td>
# </tr>
# <tr>
# <td>Kadek Duwi Aditiya</td>
# <td>2257021004</td>
# <td>Akuntansi Sektor Publik (D4)</td>
# <td>FE</td>
# </tr>
# <tr>
# <td>Ni Luh Putu Cintya Karmayani</td>
# <td>2217041086</td>
# <td>Manajemen</td>
# <td>FE</td>
# </tr>
# </table>
# Ditetapkan di Singaraja
# REKTOR,
# I WAYAN LASMAWAN
# NIP 196702211993031002
#    Score: 0.5000 | Text: LAMPIRAN > TIK: 1. I Ketut Resika Arthana, S.T., M.Kom.
# 2. Ida Komang Widhiarjaya S.T., M.Pd.
# 3. Made Yuda Sadewa S.Pd.
#    Score: 0.5000 | Text: LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA: **NOMOR** 2525/UN48/KM/2024
# **TANGGAL** 3 SEPTEMBER2024
# **TENTANG DUTA KETERBUKAAN INFORMASI PUBLIK UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2024**
# **Pengarah** : Prof. Dr. I Wayan Lasmawan, M.Pd.
# **Penanggung jawab** :
# 1. Prof. Dr. Gede Rasben Dantes, S.T., M.T.I.
# 2. Prof. Dr. I Wayan Artanayasa, S.Pd., M.Pd.
# 3. Prof. Dr. Drs. I Ketut Sudiana, M.Kes.
# 4. Drs. I Made Yasa, M.Pd.
# 5. Prof. Dr. Komang Setemen, S.Si., M.T.
# 6. I Made Karunia, S.T., M.Kom.
# **Dosen Pendamping** :
# 1. Dr. Kadek Wirahyuni, S.Pd., M.Pd.
# 2. I Kadek Edi Yudiana, M.Pd.
# **Ketua** : Cahya Palasari
# <table>
# <thead>
# <tr>
# <th></th>
# <th>Nama</th>
# <th>NIM</th>
# <th>Prodi</th>
# <th>Fakultas</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td rowspan="13">Anggota</td>
# <td>I Gusti Ayu Gita Dewi Maheswari</td>
# <td>2115051054</td>
# <td>Pendidikan Teknik Informatika</td>
# <td>FTK</td>
# </tr>
# <tr>
# <td>Wayan Restu Cahyana</td>
# <td>2215101035</td>
# <td>Ilmu Komputer</td>
# <td>FTK</td>
# </tr>
# <tr>
# <td>I Putu Duta Mahardika</td>
# <td>2118011045</td>
# <td>Kedokteran</td>
# <td>FK</td>
# </tr>
# <tr>
# <td>Ketut Lingga Amritiya</td>
# <td>2218011019</td>
# <td>Kedokteran</td>
# <td>FK</td>
# </tr>
# <tr>
# <td>Putu Vina Aryadnyani</td>
# <td>2111031135</td>
# <td>PGSD</td>
# <td>FIP</td>
# </tr>
# <tr>
# <td>Kadek Adrian Surya Indra Wirawan</td>
# <td>2211031128</td>
# <td>PGSD</td>
# <td>FIP</td>
# </tr>
# <tr>
# <td>I Putu Wahyu Mahaputra</td>
# <td>2212011016</td>
# <td>Pendidikan Bahasa dan Sastra Indonesia</td>
# <td>FBS</td>
# </tr>
# <tr>
# <td>Komang Devi Damayanti</td>
# <td>2212021072</td>
# <td>Pendidikan Bahasa Inggris</td>
# <td>FBS</td>
# </tr>
# <tr>
# <td>I Gede Maysha Sueca Darmaputra</td>
# <td>2213011098</td>
# <td>Pendidikan Matematika</td>
# <td>FMIPA</td>
# </tr>
# <tr>
# <td>Ketut Agus Sujana Putra</td>
# <td>2313031009</td>
# <td>Pendidikan Kimia</td>
# <td>FMIPA</td>
# </tr>
# <tr>
# <td>I Made Gandy Gading Sanjaya</td>
# <td>2214101114</td>
# <td>Ilmu Hukum</td>
# <td>FHIS</td>
# </tr>
# <tr>
# <td>Ni Nyoman Rita Tresnayani</td>
# <td>2214041015</td>
# <td>PPKN</td>
# <td>FHIS</td>
# </tr>
# <tr>
# <td>I Dewa Made Agus Hendra Prayoga</td>
# <td>2216011069</td>
# <td>PJKR</td>
# <td>FOK</td>
# </tr>
# <tr>
# <td></td>
# <td>Putu Bayu Sastrawan</td>
# <td>2216011105</td>
# <td>PJKR</td>
# <td>FOK</td>
# </tr>
# </tbody>
# </table>
# ---
# <table>
# <tr>
# <td>Kadek Ayu Puja Dewanti</td>
# <td>2217051158</td>
# <td>S1 Akuntansi</td>
# <td>FE</td>
# </tr>
# <tr>
# <td>Giokvannie Vernaya Tanty</td>
# <td>2217051174</td>
# <td>S1 Akuntansi</td>
# <td>FE</td>
# </tr>
# </table>
# Ditetapkan di Singaraja
# REKTOR,
# I WAYAN LASMAWAN
# NIP 196702211993031002

# %% [markdown]
# embed dengan e5 base

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter
from qdrant_client.http import models
import torch
import torch.nn.functional as F
from transformers import AutoModel, AutoTokenizer, AutoModelForMaskedLM
from qdrant_client import QdrantClient, models
from qdrant_client.models import PointStruct, SparseVector
import os
import glob
import uuid

# ==========================================
# 1. KONFIGURASI DAN UTILITAS
# ==========================================
# Model IDs
DENSE_MODEL_ID = "intfloat/multilingual-e5-base"
SPARSE_MODEL_ID = "naver/splade-v3"

# Setup Device (GPU Prioritas)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"🚀 Running on: {device}")

# --- Helper Function untuk E5-Base (Average Pooling) ---
def average_pool(last_hidden_states: torch.Tensor, attention_mask: torch.Tensor) -> torch.Tensor:
    """
    Standard pooling untuk model E5 (Average Pooling).
    Menggantikan last_token_pool yang khusus untuk Qwen/LLM decoder-only.
    """
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

class CustomEmbedder:
    def __init__(self):
        print(f"⏳ Loading Dense Model ({DENSE_MODEL_ID}) without quantization...")
        self.dense_tokenizer = AutoTokenizer.from_pretrained(DENSE_MODEL_ID)
        
        # MODIFIKASI: Load Model Tanpa Quantization Config
        self.dense_model = AutoModel.from_pretrained(
            DENSE_MODEL_ID,
            trust_remote_code=True,
            # quantization_config dihapus
            # device_map="auto" dihapus agar kita bisa kontrol manual dengan .to(device)
        )
        self.dense_model.to(device) # Pindah ke GPU/CPU secara eksplisit

        print("⏳ Loading Sparse Model (Splade v3)...")
        self.sparse_tokenizer = AutoTokenizer.from_pretrained(SPARSE_MODEL_ID)
        self.sparse_model = AutoModelForMaskedLM.from_pretrained(SPARSE_MODEL_ID)
        self.sparse_model.to(device) 

    def get_dense_vector(self, text):
        """Mengubah teks menjadi vektor dense 768 dimensi (E5-Base)"""
        # 1. Tokenize (Tambahkan "query: " jika ini adalah query, tapi untuk dokumen gunakan "passage: " sesuai paper E5)
        # Sederhananya kita tokenize biasa dulu:
        inputs = self.dense_tokenizer(
            text, 
            max_length=512, # E5 base limitnya 512, bukan 8192 (Qwen)
            padding=True, 
            truncation=True, 
            return_tensors='pt'
        )
        
        # 2. Pindahkan ke Device
        inputs = {k: v.to(self.dense_model.device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = self.dense_model(**inputs)
            # MODIFIKASI: Gunakan Average Pooling untuk E5
            embeddings = average_pool(outputs.last_hidden_state, inputs['attention_mask'])
            
            # Normalisasi
            embeddings = F.normalize(embeddings, p=2, dim=1)
            
        return embeddings[0].cpu().tolist()

    def get_sparse_vector(self, text):
        """Mengubah teks menjadi sparse vector (Splade v3)"""
        inputs = self.sparse_tokenizer(
            text, 
            return_tensors="pt", 
            padding=True, 
            truncation=True
        )
        inputs = {k: v.to(self.sparse_model.device) for k, v in inputs.items()}

        with torch.no_grad():
            outputs = self.sparse_model(**inputs)
        
        logits = outputs.logits[0]
        attention_mask = inputs["attention_mask"][0].unsqueeze(-1)
        
        relu_log = torch.log(1 + torch.relu(logits))
        weighted_log = relu_log * attention_mask
        max_val, _ = torch.max(weighted_log, dim=0)
        
        indices = torch.nonzero(max_val).squeeze().cpu().tolist()
        values = max_val[indices].cpu().tolist()
        
        if isinstance(indices, int):
            indices = [indices]
            values = [values]
            
        return SparseVector(indices=indices, values=values)

# ==========================================
# 2. MAIN LOGIC
# ==========================================

# Inisialisasi Embedder
embedder = CustomEmbedder()

# Inisialisasi Qdrant (Local Mode)
print("\n💽 Membuka database Qdrant lokal...")
client = QdrantClient(path="./qdrant_custom_db") 
COLLECTION_NAME = "hybrid_e5_splade_no_quant"

# Setup Collection
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

print("⚙️ Membuat Collection baru...")
client.create_collection(
    collection_name=COLLECTION_NAME,
    vectors_config={
        "dense_vector": models.VectorParams(
            size=768, # MODIFIKASI: E5-Base ukurannya 768, bukan 2560
            distance=models.Distance.COSINE
        )
    },
    sparse_vectors_config={
        "sparse_vector": models.SparseVectorParams()
    }
)

# --- Konfigurasi Splitter ---
# Ganti path ini sesuai path Anda
folder_path = r"C:\\Users\\Ilmu Komputer\\OneDrive\\Desktop\\portofolio\\RAG\\defi-rag-agent\\src\\evaluation\\data_md\\real_md"
md_files = glob.glob(os.path.join(folder_path, "*.md"))

headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3")]
md_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

print(f"📂 Ditemukan {len(md_files)} file Markdown.")
print("🚀 Mulai proses embedding (Tanpa Quantization)...")

points = []

# LOOP FILE & CHUNK
for file_index, file_path in enumerate(md_files):
    file_name = os.path.basename(file_path)
    
    with open(file_path, "r", encoding="utf-8") as f:
        file_content = f.read()
        
    docs = md_splitter.split_text(file_content)
    total_chunks = len(docs)
    
    print(f"\n📄 File [{file_index+1}/{len(md_files)}]: {file_name} | Total Chunks: {total_chunks}")

    for i, doc in enumerate(docs):
        raw_content = doc.page_content
        if not raw_content.strip():
            continue

        header_keys = [name for _, name in headers_to_split_on]
        found_headers = []
        for key in header_keys:
            if key in doc.metadata:
                found_headers.append(doc.metadata[key])
        
        header_breadcrumb = " > ".join(found_headers)
        
        # E5 best practice: tambahkan prefix "passage: " untuk dokumen
        # Namun jika ingin plain text, pastikan konsisten dengan query nanti
        if header_breadcrumb:
            final_text = f"passage: {header_breadcrumb}: {raw_content}" 
        else:
            final_text = f"passage: {raw_content}"

        display_header = header_breadcrumb if header_breadcrumb else "(Tanpa Header)"
        print(f"   👉 Chunk [{i+1}/{total_chunks}] | Header: {display_header}")

        # Generate vectors
        d_vec = embedder.get_dense_vector(final_text)
        s_vec = embedder.get_sparse_vector(final_text) # Splade biasanya tidak perlu prefix passage
        
        metadata = doc.metadata
        metadata["source_file"] = file_name
        metadata["chunk_index"] = i

        points.append(PointStruct(
            id=str(uuid.uuid4()), 
            vector={
                "dense_vector": d_vec,
                "sparse_vector": s_vec
            },
            payload={
                "text": final_text, # Menyimpan text asli (dengan prefix)
                "metadata": metadata
            }
        ))

# Upload ke Qdrant
if points:
    print(f"\n⬆️ Mengupload {len(points)} points ke Qdrant...")
    client.upsert(
        collection_name=COLLECTION_NAME,
        points=points
    )
    print("✅ Semua data berhasil diupload!")
else:
    print("⚠️ Tidak ada data point yang dihasilkan.")

# ==========================================
# 3. FUNGSI PENCARIAN (UPDATED)
# ==========================================
def search_hybrid(query_text):
    print(f"\n🔍 Query: '{query_text}'")
    
    # E5 best practice: tambahkan prefix "query: " untuk pencarian
    dense_query_text = f"query: {query_text}"
    
    # Embed Query
    q_dense = embedder.get_dense_vector(dense_query_text)
    q_sparse = embedder.get_sparse_vector(query_text) # Splade pakai raw text
    
    results = client.query_points(
        collection_name=COLLECTION_NAME,
        prefetch=[
            models.Prefetch(
                query=q_dense,
                using="dense_vector",
                limit=10
            ),
            models.Prefetch(
                query=q_sparse,
                using="sparse_vector",
                limit=10
            ),
        ],
        query=models.FusionQuery(fusion=models.Fusion.RRF),
        limit=3
    )
    
    for hit in results.points:
        print(f"   Score: {hit.score:.4f} | Text Sample: {hit.payload['text'][:100]}...")

# Test Case
search_hybrid("Bagaimana membuat nasi goreng dengan aroma smoky?")
# Out:
# 🚀 Running on: cuda
# ⏳ Loading Dense Model (intfloat/multilingual-e5-base) without quantization...
# ⏳ Loading Sparse Model (Splade v3)...
#
# 💽 Membuka database Qdrant lokal...
# ⚙️ Membuat Collection baru...
# 📂 Ditemukan 13 file Markdown.
# 🚀 Mulai proses embedding (Tanpa Quantization)...
#
# 📄 File [1/13]: Dukungan-Pelaksanaan-Kebijakan-Efisiensi-Belanja-APBN-Tahun-Anggaran-2025pdf.md | Total Chunks: 1
#    👉 Chunk [1/1] | Header: KEMENTERIAN KEUANGAN REPUBLIK INDONESIA > DIREKTORAT JENDERAL PERBENDAHARAAN
#
# 📄 File [2/13]: Dukungan-Pelaksanaan-Kebijakan-Pemerintahpdf.md | Total Chunks: 1
#    👉 Chunk [1/1] | Header: KEMENTERIAN KEUANGAN REPUBLIK INDONESIA > DIREKTORAT JENDERAL PERBENDAHARAAN
#
# 📄 File [3/13]: Efisiensi-KL-TA-2025_250130_133808.md | Total Chunks: 2
#    👉 Chunk [1/2] | Header: REPUBLIK INDONESIA
#    👉 Chunk [2/2] | Header: REPUBLIK INDONESIA > IDENTIFIKASI RENCANA EFISIENSI
#
# 📄 File [4/13]: Inpres-1-Tahun_2025.md | Total Chunks: 3
#    👉 Chunk [1/3] | Header: (Tanpa Header)
#    👉 Chunk [2/3] | Header: PRESIDEN REPUBLIK INDONESIA > EFISIENSI BELANJA DALAM PELAKSANAAN ANGGARAN PENDAPATAN DAN BELANJA NEGARA DAN ANGGARAN PENDAPATAN DAN BELANJA DAERAH > TAHUN ANGGARAN 2025
#    👉 Chunk [3/3] | Header: PRESIDEN REPUBLIK INDONESIA > 2. Menteri Dalam Negeri untuk:
#
# 📄 File [5/13]: panduan-app-spkdriver.md | Total Chunks: 4
#    👉 Chunk [1/4] | Header: (Tanpa Header)
#    👉 Chunk [2/4] | Header: PANDUAN > PENGGUNAAN APLIKASI SPK-DRIVER USER DRIVER > Universitas Pendidikan Ganesha
#    👉 Chunk [3/4] | Header: PANDUAN APP SPK-DRIVER
#    👉 Chunk [4/4] | Header: PANDUAN APP SPK-DRIVER > 8. Data berhasil ditambahkan dan halama serta status sudah berubah
#
# 📄 File [6/13]: panduan_prestasi.md | Total Chunks: 16
#    👉 Chunk [1/16] | Header: PANDUAN > SIMKATMAWA
#    👉 Chunk [2/16] | Header: Proses Bisnis SIMKATMAWA
#    👉 Chunk [3/16] | Header: Proses Bisnis SIMKATMAWA > Alur Singkat SIMKATMAWA :
#    👉 Chunk [4/16] | Header: Alur Pengajuan Program Kerja
#    👉 Chunk [5/16] | Header: Alur Pengajuan Proposal
#    👉 Chunk [6/16] | Header: PANDUAN LOGIN :
#    👉 Chunk [7/16] | Header: PANDUAN LOGIN : > 4. Menu Pembiayaan
#    👉 Chunk [8/16] | Header: 5. Menu Prestasi > Interface Screenshot - Daftar Prestasi Lomba
#    👉 Chunk [9/16] | Header: 5. Menu Prestasi > A. Lomba Mandiri
#    👉 Chunk [10/16] | Header: 5. Menu Prestasi > Form Interface Screenshot
#    👉 Chunk [11/16] | Header: 5. Menu Prestasi > Form Detail Lomba
#    👉 Chunk [12/16] | Header: 5. Menu Prestasi > Form Dosen Pembimbing. Klik Simpan jika data yang diinputkan dirasa sudah benar.
#    👉 Chunk [13/16] | Header: 5. Menu Prestasi > C. Sertifikasi
#    👉 Chunk [14/16] | Header: 5. Menu Prestasi > D. Wirausaha
#    👉 Chunk [15/16] | Header: 5. Menu Prestasi > Detail Wirausaha
#    👉 Chunk [16/16] | Header: SELAMAT MENCOBA 😊
#
# 📄 File [7/13]: pengumuman_beasiswa_ganesha-2025.md | Total Chunks: 8
#    👉 Chunk [1/8] | Header: (Tanpa Header)
#    👉 Chunk [2/8] | Header: PENGUMUMAN
#    👉 Chunk [3/8] | Header: PENGUMUMAN > SELEKSI BEASISWA GANESHA TAHUN 2025
#    👉 Chunk [4/8] | Header: PENGUMUMAN > A. Persyaratan > (1) Bagi Mahasiswa Tidak Mampu
#    👉 Chunk [5/8] | Header: PENGUMUMAN > A. Persyaratan > (2) Bagi Mahasiswa Berprestasi
#    👉 Chunk [6/8] | Header: PENGUMUMAN > (3) Mahasiswa yang Aktif Berkegiatan di Organisasi Mahasiswa (BEM REMA)
#    👉 Chunk [7/8] | Header: PENGUMUMAN > B. Prosedur Seleksi
#    👉 Chunk [8/8] | Header: LEMBAR PENILAIAN KEPRIBADIAN CALON PELAMAR BEASISWA GANESHA UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [8/13]: Signed-SK-Rektor-tentang-Kewajiban-Publikasi-dan-Sitasi-2025.md | Total Chunks: 12
#    👉 Chunk [1/12] | Header: KEMENTERIAN PENDIDIKAN TINGGI, SAINS, DAN TEKNOLOGI > UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [2/12] | Header: KEPUTUSAN > TENTANG > REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [3/12] | Header: LAMPIRAN
#    👉 Chunk [4/12] | Header: LAMPIRAN > I. DEFINISI KARYA ILMIAH
#    👉 Chunk [5/12] | Header: LAMPIRAN > II. KLASIFIKASI KARYA ILMIAH > 1. JURNAL ILMIAH
#    👉 Chunk [6/12] | Header: LAMPIRAN > 2. ARTIKEL YANG DISAJIKAN DALAM SEMINAR (PROSIDING) > A. Artikel Disajikan dalam Seminar Internasional
#    👉 Chunk [7/12] | Header: LAMPIRAN > 2. ARTIKEL YANG DISAJIKAN DALAM SEMINAR (PROSIDING) > B. Artikel Disajikan dalam Seminar Nasional
#    👉 Chunk [8/12] | Header: LAMPIRAN > 3. KEKAYAAN INTELEKTUAL
#    👉 Chunk [9/12] | Header: LAMPIRAN > III. KEWAJIBAN PUBLIKASI DAN KEKAYAAN INTELEKTUAL > A. KETENTUAN UMUM
#    👉 Chunk [10/12] | Header: LAMPIRAN > A.2. Kekayaan Intelektual (KI)
#    👉 Chunk [11/12] | Header: LAMPIRAN > B. KETENTUAN KHUSUS
#    👉 Chunk [12/12] | Header: LAMPIRAN > IV. KEWAJIBAN SITASI
#
# 📄 File [9/13]: SK-2525-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-UNDIKSHA-2024.md | Total Chunks: 4
#    👉 Chunk [1/4] | Header: (Tanpa Header)
#    👉 Chunk [2/4] | Header: UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2024
#    👉 Chunk [3/4] | Header: UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2024 > MEMUTUSKAN:
#    👉 Chunk [4/4] | Header: LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [10/13]: SK-3299-SK-Tim-Pejabat-PPID-Undiksha-2023.md | Total Chunks: 9
#    👉 Chunk [1/9] | Header: (Tanpa Header)
#    👉 Chunk [2/9] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > NOMOR 3299/UN48/PT/2023 > TENTANG
#    👉 Chunk [3/9] | Header: LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#    👉 Chunk [4/9] | Header: LAMPIRAN > Tim Pertimbangan Pelayanan Informasi
#    👉 Chunk [5/9] | Header: LAMPIRAN > Publikasi
#    👉 Chunk [6/9] | Header: LAMPIRAN > Dokumentasi dan Arsip Layanan Informasi
#    👉 Chunk [7/9] | Header: LAMPIRAN > TIK
#    👉 Chunk [8/9] | Header: LAMPIRAN > Penanganan Pengaduan Rektorat
#    👉 Chunk [9/9] | Header: LAMPIRAN > Penanganan Pengaduan Fakultas/Pascasarjana/Lembaga (IT/Publikasi dan Humas)
#
# 📄 File [11/13]: SK-814-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-MAHASISWA-TAHUN-2025.md | Total Chunks: 6
#    👉 Chunk [1/6] | Header: (Tanpa Header)
#    👉 Chunk [2/6] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025
#    👉 Chunk [3/6] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > Menimbang :
#    👉 Chunk [4/6] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > Mengingat :
#    👉 Chunk [5/6] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) MAHASISWA UNIVERSITAS PENDIDIKAN GANESHA TAHUN 2025 > MEMUTUSKAN:
#    👉 Chunk [6/6] | Header: LAMPIRAN > KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA
#
# 📄 File [12/13]: SK-815-DUTA-KETERBUKAAN-INFORMASI-PUBLIK-ALUMNI-TAHUN-2025.md | Total Chunks: 2
#    👉 Chunk [1/2] | Header: (Tanpa Header)
#    👉 Chunk [2/2] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DUTA KETERBUKAAN INFORMASI PUBLIK (KIP) ALUMNI UNIVERSITAS PENDIDIKAN GANESHA MASA BHAKTI TAHUN 2025-2026 > REKTOR UNIVERSITAS PENDIDIKAN GANESHA,
#
# 📄 File [13/13]: SK-Daftar-Informasi-Informasi-Publik-Undiksha-Tahun-2024.md | Total Chunks: 8
#    👉 Chunk [1/8] | Header: (Tanpa Header)
#    👉 Chunk [2/8] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > NOMOR 571/UN48/PT/2024 > TENTANG
#    👉 Chunk [3/8] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > Menimbang
#    👉 Chunk [4/8] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > Mengingat
#    👉 Chunk [5/8] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > MEMUTUSKAN:
#    👉 Chunk [6/8] | Header: KEPUTUSAN REKTOR UNIVERSITAS PENDIDIKAN GANESHA > DAFTAR INFORMASI PUBLIK YANG WAJIB DISEDIAKAN DAN DIUMUMKAN SECARA BERKALA
#    👉 Chunk [7/8] | Header: DAFTAR INFORMASI PUBLIK YANG WAJIB TERSEDIA SETIAP SAAT
#    👉 Chunk [8/8] | Header: DAFTAR INFORMASI DIKECUALIKAN YANG HABIS JANGKA WAKTU PENGECUALIAN SEBAGAI INFORMASI TERBUKA
#
# ⬆️ Mengupload 76 points ke Qdrant...
# ✅ Semua data berhasil diupload!
#
# 🔍 Query: 'Bagaimana membuat nasi goreng dengan aroma smoky?'
#    Score: 0.5000 | Text Sample: passage: 5. Menu Prestasi > C. Sertifikasi: Form ini digunakan untuk pendataan dan verifikasi sertif...
#    Score: 0.5000 | Text Sample: passage: KEPUTUSAN > TENTANG > REKTOR UNIVERSITAS PENDIDIKAN GANESHA: **Menimbang** : a. bahwa dalam...
#    Score: 0.3333 | Text Sample: passage: SALINAN...
