# %%
import requests
model_name = "eramax/gemma-7b-it:q4_k_m"
model_name1 = "gemma:7b"
url = "http://localhost:11434/api/generate"

payload = {
    "model": model_name1,
    "prompt": "siapa presiden indonesia saat ini?",
    "stream": False
}

response = requests.post(url, json=payload)
print(response.json()["response"])
# Out:
# Saat ini, tanggal 28 Oktober 2023, Presiden Indonesia adalah **Jokowi**.

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="gemma:7b")
print(llm.invoke("Siapa presiden Indonesia saat ini?"))
# Out:
# Saat ini, presiden Indonesia adalah **Jokowi**.
